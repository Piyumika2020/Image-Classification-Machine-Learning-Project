# %% [markdown]
# ML Image classification project to identify seperatly Cristiano Ronaldo and Messi.

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [raw]
# Imports cv2 from opencv lib, that have been installed my pc where is located python. It will be used for Reading images, Face detection, Object detection Image resizing and cropping.
